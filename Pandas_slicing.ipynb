# %%
import pandas as pd

player_list = [['M.S.Dhoni', 36, 75, 5428000],
               ['A.B.D Villers', 38, 74, 3428000],
               ['V.Kohli', 31, 70, 8428000],
               ['S.Smith', 34, 80, 4428000],
               ['C.Gayle', 40, 100, 4528000],
               ['J.Root', 33, 72, 7028000],
               ['K.Peterson', 42, 85, 2528000]]

df = pd.DataFrame(player_list, columns=['Name', 'Age', 'Weight', 'Salary'])
print(df)
df.ndim
# Out:
#             Name  Age  Weight   Salary
# 0      M.S.Dhoni   36      75  5428000
# 1  A.B.D Villers   38      74  3428000
# 2        V.Kohli   31      70  8428000
# 3        S.Smith   34      80  4428000
# 4        C.Gayle   40     100  4528000
# 5         J.Root   33      72  7028000
# 6     K.Peterson   42      85  2528000
# 2

# %% [markdown]
# ## Slicing Using iloc[] (Integer-Based Indexing)
# ### The iloc[] method in Pandas allows us to extract specific rows and columns based on their integer positions starting from 0

# %%
df1 = df.iloc[0:4]
print(df1)
# Out:
#             Name  Age  Weight   Salary
# 0      M.S.Dhoni   36      75  5428000
# 1  A.B.D Villers   38      74  3428000
# 2        V.Kohli   31      70  8428000
# 3        S.Smith   34      80  4428000

# %% [markdown]
# ## Slicing Columns in dataframe
# ### Column slicing means selecting a specific set of columns from the DataFrame while keeping all rows.

# %%
df1 = df.iloc[:, 0:2]

print(df1)
# Out:
#             Name  Age
# 0      M.S.Dhoni   36
# 1  A.B.D Villers   38
# 2        V.Kohli   31
# 3        S.Smith   34
# 4        C.Gayle   40
# 5         J.Root   33
# 6     K.Peterson   42

# %% [markdown]
# ## Selecting a Specific Cell in a Pandas DataFrame
# ### If you need a single value from a DataFrame you can specify the exact row and column position

# %%
value = df.iloc[2, 3]  
print("Specific Cell Value:", value)
# Out:
# Specific Cell Value: 8428000

# %% [markdown]
# ## Using Boolean Conditions in a Pandas DataFrame
# ### Instead of selecting rows by index we can use Boolean conditions (e.g., Age > 35) to filter rows dynamically

# %%
data = df[df['Age'] > 35].iloc[:, :] 
print("\nFiltered Data based on Age > 35:\n", data)
# Out:
# Filtered Data based on Age > 35:
#              Name  Age  Weight   Salary
# 0      M.S.Dhoni   36      75  5428000
# 1  A.B.D Villers   38      74  3428000
# 4        C.Gayle   40     100  4528000
# 6     K.Peterson   42      85  2528000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     7 non-null      int64
#  2   Weight  7 non-null      int64
#  3   Salary  7 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 356.0+ bytes

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Weight', 'Salary'], dtype='object')

# %%
df.isnull()
# Out:
#     Name    Age  Weight  Salary
# 0  False  False   False   False
# 1  False  False   False   False
# 2  False  False   False   False
# 3  False  False   False   False
# 4  False  False   False   False
# 5  False  False   False   False
# 6  False  False   False   False

# %%
>>> df.rename(columns={"Age":"Boyokh" }, errors="raise")
# Out:
#             Name  Boyokh  Weight   Salary
# 0      M.S.Dhoni      36      75  5428000
# 1  A.B.D Villers      38      74  3428000
# 2        V.Kohli      31      70  8428000
# 3        S.Smith      34      80  4428000
# 4        C.Gayle      40     100  4528000
# 5         J.Root      33      72  7028000
# 6     K.Peterson      42      85  2528000

# %%
df.sort_values(by='Age', ascending=False).head()
# Out:
#             Name  Age  Weight   Salary
# 6     K.Peterson   42      85  2528000
# 4        C.Gayle   40     100  4528000
# 1  A.B.D Villers   38      74  3428000
# 0      M.S.Dhoni   36      75  5428000
# 3        S.Smith   34      80  4428000

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# importing necessary module.
import pandas as pd

# creating a DataFrame.
dataFrame = pd.DataFrame({
    'id': [101, 102, 103, 104, 105, 106, 107],
    'address': ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'sales': [10, 500, 48, 12, 21, 22, 14]
})

# Let us group the data using a certain value.
dataFrame['totalSales'] = dataFrame.groupby('address')['sales'].transform('sum')

# printing the result.
print(dataFrame)
# Out:
#     id address  sales  totalSales
# 0  101       A     10          10
# 1  102       B    500         500
# 2  103       C     48          48
# 3  104       D     12          12
# 4  105       E     21          21
# 5  106       F     22          22
# 6  107       G     14          14

# %%
df['Name']
# Out:
# 0        M.S.Dhoni
# 1    A.B.D Villers
# 2          V.Kohli
# 3          S.Smith
# 4          C.Gayle
# 5           J.Root
# 6       K.Peterson
# Name: Name, dtype: object
